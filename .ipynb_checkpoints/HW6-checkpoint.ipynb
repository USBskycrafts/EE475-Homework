# %%
datapath = './nonlinear_superlearn_datasets/'

import autograd.numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ---
# # Some Handy Tools

# %%
from autograd import grad
from autograd import hessian
def newtons_method(g, max_its, w):
    gradient = grad(g)
    hess = hessian(g)
    epsilon = 1e-7
    
    weight_his = [w]
    cost_his = [g(w)]
    for k in range(max_its):
        grad_eval = gradient(w)
        hess_eval = hess(w)
        
        hess_eval.shape = (int(np.size(hess_eval)**0.5),
                           int(np.size(hess_eval)**0.5))
        A = hess_eval + epsilon*np.eye(w.size)
        b = grad_eval
        w = np.linalg.solve(A, np.dot(A,w)-b)
        weight_his.append(w)
        cost_his.append(g(w))
    return weight_his, cost_his

def gradient_descent(g, max_its, w):
    gradient = grad(g)
    weight_his = [w]
    cost_his = [g(w)]
    for k in range(max_its):
        grad_eval = gradient(w)
        w = w - grad_eval
        weight_his.append(w)
        cost_his.append(g(w))
    return weight_his, cost_his

# %% [markdown]
# ---

# %% [markdown]
# # 10.4

# %% [markdown]
# (a)

# %% [markdown]
# $$
# f(y) = log(y)
# $$

# %% [markdown]
# (b)

# %%
# import the dataset
csvname = datapath + 'transistor_counts.csv'
data = np.asarray(pd.read_csv(csvname,header = None))
x = data[:,0]
x.shape = (len(x),1)
y = data[:,1]
y.shape = (len(y),1)
x = x.T
y = y.T
print(x.shape, y.shape)


def feature_transforms(a):
    f = np.log2(a.T)
    return f.T

def norm(x):
    mu = np.sum(np.array(x), 1) / float(x.shape[1])
    tmp = np.apply_along_axis(lambda x : x - mu, 0, x)
    sigma = np.sqrt(np.sum(np.apply_along_axis(lambda x : x - mu, 0, x)**2, 1) / float(x.shape[1]))
    x = np.apply_along_axis(lambda x : (x - mu) / sigma, 0, x)
    return x

def model(x, w):
    x = norm(x)
    a = w[0] + np.dot(x.T, w[1:])
    return a.T

def least_squares(w):
    cost = np.sum((model(x, w) - feature_transforms(y))**2)
    return cost/float(y.size)

def train():
    theta = np.ones((2, 1))
    weight_his, _ = newtons_method(least_squares, 1000, theta)
    print(weight_his[-1])
    return weight_his[-1]

weight = train()
# Out:
# (1, 85) (1, 85)
# [[23.95458172]
#  [ 6.61301065]]

# %% [markdown]
# Now we plot the result

# %%
plt.plot(x.T, np.log2(y.T))
plt.plot(x.T, model(x, weight).T)

# %%
plt.plot(x.T, y.T)
plt.plot(x.T, np.power(2, model(x, weight).T))

# %% [markdown]
# # 10.8

# %%
csvname = datapath + 'diagonal_stripes.csv'
data = np.loadtxt(csvname, delimiter=',')

x = data[:2,:]
y = data[2:,:]

print(np.shape(x))
print(np.shape(y))
# Out:
# (2, 300)
# (1, 300)

# %%
def feature_transforms(x, w):
    #print(x.shape, w.shape)
    f = np.sin(w[0] + np.dot(x.T, w[1:]))
    return f.T

def classifer(x, theta):
    x = norm(x)
    f = feature_transforms(x, theta[0])
    a = theta[1][0] + np.dot(f.T, theta[1][1])
    return a

def softmax(w):
    global y
    y = norm(y)
    cost = np.sum(np.log(1+np.exp(-y*classifer(x,w))))
    return cost/float(np.size(y))

def train():
    theta = 3 * np.ones((2, 3))
    weight_his, _ = gradient_descent(softmax, 1000, theta)
    return weight_his[-1]

weight = train()
print(weight)
# Out:
# [[ 1.2622564   2.04796658  3.76045335]
#  [-0.05044565  5.61612279  3.        ]]

# %%
mis_classified = np.sum(np.apply_along_axis(lambda x : 1 if x < 0 else 0, 0, (y*classifer(x, weight))))
print(f"There are {mis_classified} mismatches in total")
# Out:
# There are 27 mismatches in total

# %% [markdown]
# # 11.1

# %%
csvname = datapath + 'noisy_sin_sample.csv'

data = np.loadtxt(csvname, delimiter = ',')
x = data[:-1,:]
y = data[-1:,:] 

print(np.shape(x))
print(np.shape(y))

def train():
    global x, y
    p = np.random.permutation(len(x))
    x = x[p]
    y = y[p]
    training_set = zip(x[0][0:14], y[0][0:14])
    testing_set = zip(x[0][14:], y[0][14:])
    ws = []
    for cap in range(8):
        x, y = zip(*training_set)
        x = np.array(x)
        y = np.array(y)
        w = np.random.rand(1, cap)
               
        def model(x, w):
            f = 0
            for i in range(cap):
                f += (x**i) * w[i]
            return f

        def least_squares(w):
            print(x.shape, y.shape)
            cost = np.sum((model(x, w) - y)**2)
            return cost/float(y.size)
              
        loss = lambda w : least_squares(w)
        w, _ = gradient_descent(loss, 1000, w)
        ws.append(w[-1])
    return ws

train()
# Out:
# (1, 21)
# (1, 21)
# (14,) (14,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 39
#      36         ws.append(w[-1])
#      37     return ws
# ---> 39 train()
#
# Cell In[39], line 35, in train()
#      33     w = np.random.rand(1, cap)
#      34     loss = lambda w : least_squares(w)
# ---> 35     w, _ = gradient_descent(loss, 1000, w)
#      36     ws.append(w[-1])
#      37 return ws
#
# Cell In[2], line 26, in gradient_descent(g, max_its, w)
#      24 gradient = grad(g)
#      25 weight_his = [w]
# ---> 26 cost_his = [g(w)]
#      27 for k in range(max_its):
#      28     grad_eval = gradient(w)
#
# Cell In[39], line 34, in train.<locals>.<lambda>(w)
#      32 y = np.array(y)
#      33 w = np.random.rand(1, cap)
# ---> 34 loss = lambda w : least_squares(w)
#      35 w, _ = gradient_descent(loss, 1000, w)
#      36 ws.append(w[-1])
#
# Cell In[39], line 18, in least_squares(w)
#      16 def least_squares(w):
#      17     print(x.shape, y.shape)
# ---> 18     cost = np.sum((model(x, w) - y)**2)
#      19     return cost/float(y.size)
#
# Cell In[39], line 12, in model(x, w)
#      10 def model(x, w):
#      11     f = 0
# ---> 12     for i in range(cap):
#      13         f += (x**i) * w[i]
#      14     return f
#
# NameError: name 'cap' is not defined

# %% [markdown]
# # 11.3
